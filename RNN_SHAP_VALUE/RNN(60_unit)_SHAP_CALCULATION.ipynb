# %%
# Install required packages
# !pip install torch numpy shap pandas -q

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
import shap
import random
import pandas as pd
from datetime import datetime


# REPRODUCIBILITY

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)


# CONFIG

HIDDEN_SIZE = 60
EPOCHS = 300
BATCH_SIZE = 32
LR = 0.001
MAX_N = 8

FEATURE_NAMES = ['X', 'Y', 'A', 'B', 'EOS']
symbol_to_idx = {'X': 0, 'Y': 1, 'A': 2, 'B': 3, 'EOS': 4}


# DATA GENERATION

def generate_sequence():
    valid = np.random.rand() > 0.5
    rule  = np.random.choice(['X', 'Y'])
    n     = np.random.randint(1, MAX_N + 1)

    seq = [rule] + ['A'] * n

    if rule == 'X':
        seq += ['B'] * (n if valid else n + np.random.choice([-1, 1]))
    else:
        seq += ['B'] * (2*n if valid else 2*n + np.random.choice([-1, 1]))

    seq.append('EOS')
    onehot = np.eye(5)[[symbol_to_idx[s] for s in seq]]
    return onehot, float(valid)

class GrammarDataset(Dataset):
    def __init__(self, n_samples=2000):
        self.data = [generate_sequence() for _ in range(n_samples)]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x, y = self.data[idx]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y)

def collate(batch):
    xs, ys = zip(*batch)
    max_len = max(x.shape[0] for x in xs)
    padded = [torch.cat([x, torch.zeros(max_len - x.shape[0], 5)], 0) for x in xs]
    return torch.stack(padded), torch.tensor(ys)


# MODEL

class RNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.RNN(5, HIDDEN_SIZE, batch_first=True)
        self.fc = nn.Linear(HIDDEN_SIZE, 1)

    def forward(self, x):
        _, h = self.rnn(x)
        return self.fc(h.squeeze(0))


# SHAP FUNCTION

def compute_shap(model, dataset):
    model.eval()

    SEQ_LEN = max(dataset.data[i][0].shape[0] for i in range(len(dataset.data)))

    def to_flat(indices):
        items = []
        for i in indices:
            x, _ = dataset.data[i]
            pad_len = SEQ_LEN - x.shape[0]
            if pad_len > 0:
                x = np.concatenate([x, np.zeros((pad_len, 5))], 0)
            items.append(x.reshape(-1))
        return torch.tensor(np.stack(items), dtype=torch.float32)

    background = to_flat(range(0, 80))
    explain    = to_flat(range(80, 120))

    class Wrapper(nn.Module):
        def __init__(self, base_model):
            super().__init__()
            self.base_model = base_model

        def forward(self, x_flat):
            x = x_flat.view(-1, SEQ_LEN, 5)
            return self.base_model(x)

    wrapper = Wrapper(model)
    explainer = shap.GradientExplainer(wrapper, background)

    shap_vals = explainer.shap_values(explain)
    if isinstance(shap_vals, list):
        shap_vals = shap_vals[0]

    shap_vals = np.array(shap_vals)
    shap_3d = shap_vals.reshape(shap_vals.shape[0], SEQ_LEN, 5)
    shap_mean = np.mean(np.abs(shap_3d), axis=(0,1))

    return shap_mean


# TRAIN FUNCTION

def train_model_with_shap(model, train_loader, test_loader, full_dataset):
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    criterion = nn.BCEWithLogitsLoss()

    results = []

    for epoch in range(EPOCHS):
        # Train
        model.train()
        for x, y in train_loader:
            optimizer.zero_grad()
            logits = model(x).squeeze()
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

        # Evaluate
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for x, y in test_loader:
                logits = model(x).squeeze()
                probs = torch.sigmoid(logits)
                preds = (probs > 0.5).float()
                correct += (preds == y).sum().item()
                total += y.size(0)

        acc = correct / total

        # Compute SHAP
        print(f"Epoch {epoch+1}/{EPOCHS} | Computing SHAP...", end='\r')
        shap_mean = compute_shap(model, full_dataset)

        # Calculate total SHAP (sum of all features)
        total_shap = float(np.sum(shap_mean))

        # Store results
        epoch_result = {
            'epoch': epoch + 1,
            'accuracy': acc,
            'shap_X': float(shap_mean[0]),
            'shap_Y': float(shap_mean[1]),
            'shap_A': float(shap_mean[2]),
            'shap_B': float(shap_mean[3]),
            'shap_EOS': float(shap_mean[4]),
            'shap_total': total_shap
        }
        results.append(epoch_result)

        if (epoch+1) % 10 == 0:
            print(f"Epoch {epoch+1}/{EPOCHS} | Test Acc: {acc:.4f} | SHAP: X={shap_mean[0]:.4f}, Y={shap_mean[1]:.4f}, A={shap_mean[2]:.4f}, B={shap_mean[3]:.4f}, EOS={shap_mean[4]:.4f}, Total={total_shap:.4f}")

    return results


# MAIN EXECUTION

print("=" * 80)
print("Training RNN Model with SHAP Analysis")
print("=" * 80)
print()

# Create dataset
full_dataset = GrammarDataset(n_samples=2000)

train_size = int(0.8 * len(full_dataset))
test_size  = len(full_dataset) - train_size

train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                          shuffle=True, collate_fn=collate)

test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                          shuffle=False, collate_fn=collate)

# Train model
model = RNNModel()
results = train_model_with_shap(model, train_loader, test_loader, full_dataset)

# Convert to DataFrame
df = pd.DataFrame(results)

# Reorder columns for better readability
df = df[['epoch', 'accuracy', 'shap_X', 'shap_Y', 'shap_A', 'shap_B', 'shap_EOS', 'shap_total']]

# Save to CSV
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"rnn_shap_results_{timestamp}.csv"
df.to_csv(csv_filename, index=False)

print()
print("=" * 80)
print(f"Training Complete!")
print("=" * 80)
print(f"Final Accuracy: {results[-1]['accuracy']:.4f}")
print(f"Final Total SHAP: {results[-1]['shap_total']:.4f}")
print(f"\nResults saved to: {csv_filename}")
print()
print("First 5 rows:")
print(df.head())
print()
print("Last 5 rows:")
print(df.tail())
print()
print("Summary Statistics:")
print(df.describe())

# Download the CSV file (for Colab)
from google.colab import files
files.download(csv_filename)
print(f"\n✓ CSV file downloaded: {csv_filename}")
# Out:
# ================================================================================
# Training RNN Model with SHAP Analysis
# ================================================================================
#
# Epoch 10/300 | Test Acc: 0.5950 | SHAP: X=0.0000, Y=0.0001, A=0.0017, B=0.0170, EOS=0.0073, Total=0.0262
# Epoch 20/300 | Test Acc: 0.5650 | SHAP: X=0.0000, Y=0.0000, A=0.0001, B=0.0048, EOS=0.0023, Total=0.0072
# Epoch 30/300 | Test Acc: 0.7125 | SHAP: X=0.0011, Y=0.0059, A=0.0087, B=0.0936, EOS=0.0212, Total=0.1305
# Epoch 40/300 | Test Acc: 0.6700 | SHAP: X=0.0003, Y=0.0027, A=0.0038, B=0.0641, EOS=0.0104, Total=0.0813
# Epoch 50/300 | Test Acc: 0.6900 | SHAP: X=0.0002, Y=0.0106, A=0.0057, B=0.0764, EOS=0.0280, Total=0.1210
# Epoch 60/300 | Test Acc: 0.9475 | SHAP: X=0.0013, Y=0.0345, A=0.0337, B=0.2406, EOS=0.0989, Total=0.4090
# Epoch 70/300 | Test Acc: 1.0000 | SHAP: X=0.0030, Y=0.1006, A=0.0841, B=0.5776, EOS=0.2525, Total=1.0178
# Epoch 80/300 | Test Acc: 1.0000 | SHAP: X=0.0028, Y=0.0975, A=0.1057, B=0.5360, EOS=0.2440, Total=0.9860
# Epoch 90/300 | Test Acc: 1.0000 | SHAP: X=0.0034, Y=0.1069, A=0.0866, B=0.4229, EOS=0.2005, Total=0.8203
# Epoch 100/300 | Test Acc: 0.5675 | SHAP: X=0.0028, Y=0.0027, A=0.0051, B=0.0282, EOS=0.0089, Total=0.0475
# Epoch 110/300 | Test Acc: 0.5550 | SHAP: X=0.0104, Y=0.0205, A=0.0129, B=0.0502, EOS=0.0367, Total=0.1306
# Epoch 120/300 | Test Acc: 0.8900 | SHAP: X=0.0305, Y=0.0581, A=0.0210, B=0.1750, EOS=0.0870, Total=0.3717
# Epoch 130/300 | Test Acc: 0.9350 | SHAP: X=0.0441, Y=0.0884, A=0.0375, B=0.3151, EOS=0.1352, Total=0.6203
# Epoch 140/300 | Test Acc: 0.9800 | SHAP: X=0.0595, Y=0.1307, A=0.0341, B=0.3041, EOS=0.1469, Total=0.6754
# Epoch 150/300 | Test Acc: 1.0000 | SHAP: X=0.0494, Y=0.1125, A=0.0417, B=0.3736, EOS=0.1677, Total=0.7449
# Epoch 160/300 | Test Acc: 1.0000 | SHAP: X=0.0875, Y=0.2157, A=0.0444, B=0.3504, EOS=0.1760, Total=0.8739
# Epoch 170/300 | Test Acc: 1.0000 | SHAP: X=0.0611, Y=0.1196, A=0.0340, B=0.3834, EOS=0.1606, Total=0.7587
# Epoch 180/300 | Test Acc: 1.0000 | SHAP: X=0.0920, Y=0.1944, A=0.0378, B=0.4162, EOS=0.1688, Total=0.9092
# Epoch 190/300 | Test Acc: 1.0000 | SHAP: X=0.0980, Y=0.1918, A=0.0400, B=0.4141, EOS=0.1782, Total=0.9221
# Epoch 200/300 | Test Acc: 1.0000 | SHAP: X=0.0752, Y=0.1538, A=0.0442, B=0.4558, EOS=0.2084, Total=0.9374
# Epoch 210/300 | Test Acc: 0.9650 | SHAP: X=0.0565, Y=0.0955, A=0.0322, B=0.1548, EOS=0.0799, Total=0.4190
# Epoch 220/300 | Test Acc: 0.9950 | SHAP: X=0.0576, Y=0.0939, A=0.0440, B=0.2417, EOS=0.1054, Total=0.5426
# Epoch 230/300 | Test Acc: 0.9900 | SHAP: X=0.0741, Y=0.1157, A=0.0438, B=0.2529, EOS=0.1181, Total=0.6047
# Epoch 240/300 | Test Acc: 0.6125 | SHAP: X=0.0922, Y=0.1925, A=0.0450, B=0.2327, EOS=0.1238, Total=0.6862
# Epoch 250/300 | Test Acc: 0.9950 | SHAP: X=0.0845, Y=0.1287, A=0.0471, B=0.2694, EOS=0.1271, Total=0.6568
# Epoch 260/300 | Test Acc: 1.0000 | SHAP: X=0.0673, Y=0.1220, A=0.0380, B=0.2449, EOS=0.1309, Total=0.6030
# Epoch 270/300 | Test Acc: 1.0000 | SHAP: X=0.0771, Y=0.1114, A=0.0446, B=0.2464, EOS=0.1326, Total=0.6122
# Epoch 280/300 | Test Acc: 0.9950 | SHAP: X=0.0786, Y=0.1516, A=0.0608, B=0.3362, EOS=0.1759, Total=0.8031
# Epoch 290/300 | Test Acc: 0.8350 | SHAP: X=0.0729, Y=0.1406, A=0.0572, B=0.3636, EOS=0.1440, Total=0.7783
# Epoch 300/300 | Test Acc: 0.9900 | SHAP: X=0.0513, Y=0.0954, A=0.0316, B=0.2736, EOS=0.1065, Total=0.5583
#
# ================================================================================
# Training Complete!
# ================================================================================
# Final Accuracy: 0.9900
# Final Total SHAP: 0.5583
#
# Results saved to: rnn_shap_results_20260225_143600.csv
#
# First 5 rows:
#    epoch  accuracy        shap_X        shap_Y        shap_A    shap_B  \
# 0      1    0.4825  3.688137e-10  4.561964e-10  7.196809e-08  0.000362
# 1      2    0.5600  2.506474e-06  2.376794e-06  4.372685e-05  0.003985
# 2      3    0.5925  3.023273e-05  1.992093e-05  3.002081e-04  0.008231
# 3      4    0.6150  1.847576e-03  2.268939e-03  9.373717e-03  0.046494
# 4      5    0.5825  5.758379e-05  1.877861e-05  6.798417e-04  0.005691
#
#    shap_EOS  shap_total
# 0  0.000259    0.000621
# 1  0.001220    0.005254
# 2  0.002858    0.011439
# 3  0.014499    0.074484
# 4  0.002842    0.009288
#
# Last 5 rows:
#      epoch  accuracy    shap_X    shap_Y    shap_A    shap_B  shap_EOS  \
# 295    296    1.0000  0.111977  0.219876  0.051949  0.338180  0.157514
# 296    297    0.9350  0.051742  0.110152  0.029068  0.242974  0.114273
# 297    298    0.9725  0.054932  0.110248  0.027968  0.235370  0.108179
# 298    299    0.9850  0.054580  0.113007  0.028701  0.250341  0.118364
# 299    300    0.9900  0.051329  0.095383  0.031615  0.273566  0.106454
#
#      shap_total
# 295    0.879497
# 296    0.548210
# 297    0.536698
# 298    0.564992
# 299    0.558348
#
# Summary Statistics:
#             epoch    accuracy        shap_X        shap_Y        shap_A  \
# count  300.000000  300.000000  3.000000e+02  3.000000e+02  3.000000e+02
# mean   150.500000    0.888717  4.153828e-02  9.245256e-02  3.631224e-02
# std     86.746758    0.168570  3.421241e-02  6.281084e-02  2.649058e-02
# min      1.000000    0.347500  3.688137e-10  4.561964e-10  7.196809e-08
# 25%     75.750000    0.806875  2.568489e-03  3.124082e-02  2.016895e-02
# 50%    150.500000    0.995000  5.227528e-02  1.026139e-01  3.672793e-02
# 75%    225.250000    1.000000  7.029615e-02  1.327920e-01  4.409493e-02
# max    300.000000    1.000000  1.308241e-01  2.553571e-01  1.356880e-01
#
#            shap_B    shap_EOS  shap_total
# count  300.000000  300.000000  300.000000
# mean     0.255321    0.117715    0.543339
# std      0.155053    0.071049    0.316738
# min      0.000362    0.000259    0.000621
# 25%      0.122816    0.061870    0.282378
# 50%      0.268337    0.131747    0.613452
# 75%      0.356780    0.161698    0.775832
# max      0.657176    0.287716    1.212630
# ✓ CSV file downloaded: rnn_shap_results_20260225_143600.csv

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr

# Load CSV files
phi_df = pd.read_csv('/content/rnn_training_summary.csv')  # Columns: 'epoch', 'phi_star'
shap_df = pd.read_csv('/content/rnn_shap_results_20260225_143600.csv')        # Columns: 'epoch', 'shap_value'

# If CSVs don't have 'epoch', we assume same order and add one
if 'epoch' not in phi_df.columns:
    phi_df['epoch'] = range(1, len(phi_df) + 1)
if 'epoch' not in shap_df.columns:
    shap_df['epoch'] = range(1, len(shap_df) + 1)

# Merge on epoch
merged_df = pd.merge(phi_df, shap_df, on='epoch')

# Compute correlations
pearson_corr, pearson_p = pearsonr(merged_df['phi'], merged_df['shap_total'])
spearman_corr, spearman_p = spearmanr(merged_df['phi'], merged_df['shap_total'])

print(f"Pearson correlation: {pearson_corr:.4f}, p-value: {pearson_p:.4e}")
print(f"Spearman correlation: {spearman_corr:.4f}, p-value: {spearman_p:.4e}")
# Out:
# Pearson correlation: -0.2766, p-value: 1.1387e-06
# Spearman correlation: -0.2201, p-value: 1.2115e-04

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV files
phi_df = pd.read_csv('/content/rnn_training_summary.csv')  # Columns: 'epoch', 'phi'
shap_df = pd.read_csv('/content/rnn_shap_results_20260225_143600.csv')  # Columns: 'epoch', 'shap_total'

# Add epoch if missing
if 'epoch' not in phi_df.columns:
    phi_df['epoch'] = range(1, len(phi_df) + 1)
if 'epoch' not in shap_df.columns:
    shap_df['epoch'] = range(1, len(shap_df) + 1)

# Merge on epoch
merged_df = pd.merge(phi_df, shap_df, on='epoch')

# Compute correlations
pearson_corr, pearson_p = pearsonr(merged_df['phi'], merged_df['shap_total'])
spearman_corr, spearman_p = spearmanr(merged_df['phi'], merged_df['shap_total'])

print(f"Pearson correlation: {pearson_corr:.4f}, p-value: {pearson_p:.4e}")
print(f"Spearman correlation: {spearman_corr:.4f}, p-value: {spearman_p:.4e}")

# Plot
plt.figure(figsize=(8,6))
sns.regplot(x='phi', y='shap_total', data=merged_df, ci=None,
            scatter_kws={'s':50, 'alpha':0.6}, line_kws={'color':'red'})
plt.title('Correlation between Φ* and SHAP values', fontsize=14)
plt.xlabel('Φ* (phi)', fontsize=12)
plt.ylabel('SHAP Total', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

# Annotate correlation coefficients
plt.text(0.05, 0.95, f"Pearson r = {pearson_corr:.4f}\nSpearman ρ = {spearman_corr:.4f}",
         transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top',
         bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray'))

plt.tight_layout()
plt.show()
# Out:
# Pearson correlation: -0.2766, p-value: 1.1387e-06
# Spearman correlation: -0.2201, p-value: 1.2115e-04

# %%
# Install required packages
# !pip install torch numpy shap pandas -q

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
import shap
import random
import pandas as pd
from datetime import datetime


# REPRODUCIBILITY

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)


# CONFIG

HIDDEN_SIZE = 60
EPOCHS = 300
BATCH_SIZE = 32
LR = 0.001
MAX_N = 8

FEATURE_NAMES = ['X', 'Y', 'A', 'B', 'EOS']
symbol_to_idx = {'X': 0, 'Y': 1, 'A': 2, 'B': 3, 'EOS': 4}


# DATA GENERATION

def generate_sequence():
    valid = np.random.rand() > 0.5
    rule  = np.random.choice(['X', 'Y'])
    n     = np.random.randint(1, MAX_N + 1)

    seq = [rule] + ['A'] * n

    if rule == 'X':
        seq += ['B'] * (n if valid else n + np.random.choice([-1, 1]))
    else:
        seq += ['B'] * (2*n if valid else 2*n + np.random.choice([-1, 1]))

    seq.append('EOS')
    onehot = np.eye(5)[[symbol_to_idx[s] for s in seq]]
    return onehot, float(valid)

class GrammarDataset(Dataset):
    def __init__(self, n_samples=2000):
        self.data = [generate_sequence() for _ in range(n_samples)]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x, y = self.data[idx]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y)

def collate(batch):
    xs, ys = zip(*batch)
    max_len = max(x.shape[0] for x in xs)
    padded = [torch.cat([x, torch.zeros(max_len - x.shape[0], 5)], 0) for x in xs]
    return torch.stack(padded), torch.tensor(ys)


# MODEL

class RNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.RNN(5, HIDDEN_SIZE, batch_first=True)
        self.fc = nn.Linear(HIDDEN_SIZE, 1)

    def forward(self, x):
        _, h = self.rnn(x)
        return self.fc(h.squeeze(0))


# SHAP FUNCTION

def compute_shap(model, dataset):
    model.eval()

    SEQ_LEN = max(dataset.data[i][0].shape[0] for i in range(len(dataset.data)))

    def to_flat(indices):
        items = []
        for i in indices:
            x, _ = dataset.data[i]
            pad_len = SEQ_LEN - x.shape[0]
            if pad_len > 0:
                x = np.concatenate([x, np.zeros((pad_len, 5))], 0)
            items.append(x.reshape(-1))
        return torch.tensor(np.stack(items), dtype=torch.float32)

    background = to_flat(range(0, 80))
    explain    = to_flat(range(80, 120))

    class Wrapper(nn.Module):
        def __init__(self, base_model):
            super().__init__()
            self.base_model = base_model

        def forward(self, x_flat):
            x = x_flat.view(-1, SEQ_LEN, 5)
            return self.base_model(x)

    wrapper = Wrapper(model)
    explainer = shap.GradientExplainer(wrapper, background)

    shap_vals = explainer.shap_values(explain)
    if isinstance(shap_vals, list):
        shap_vals = shap_vals[0]

    shap_vals = np.array(shap_vals)
    shap_3d = shap_vals.reshape(shap_vals.shape[0], SEQ_LEN, 5)
    shap_mean = np.mean(np.abs(shap_3d), axis=(0,1))

    return shap_mean


# TRAIN FUNCTION

def train_model_with_shap(model, train_loader, test_loader, full_dataset):
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    criterion = nn.BCEWithLogitsLoss()

    results = []

    for epoch in range(EPOCHS):
        # Train
        model.train()
        for x, y in train_loader:
            optimizer.zero_grad()
            logits = model(x).squeeze()
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

        # Evaluate
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for x, y in test_loader:
                logits = model(x).squeeze()
                probs = torch.sigmoid(logits)
                preds = (probs > 0.5).float()
                correct += (preds == y).sum().item()
                total += y.size(0)

        acc = correct / total

        # Compute SHAP
        print(f"Epoch {epoch+1}/{EPOCHS} | Computing SHAP...", end='\r')
        shap_mean = compute_shap(model, full_dataset)

        # Calculate total SHAP (sum of all features)
        total_shap = float(np.sum(shap_mean))

        # Store results
        epoch_result = {
            'epoch': epoch + 1,
            'accuracy': acc,
            'shap_X': float(shap_mean[0]),
            'shap_Y': float(shap_mean[1]),
            'shap_A': float(shap_mean[2]),
            'shap_B': float(shap_mean[3]),
            'shap_EOS': float(shap_mean[4]),
            'shap_total': total_shap
        }
        results.append(epoch_result)

        if (epoch+1) % 10 == 0:
            print(f"Epoch {epoch+1}/{EPOCHS} | Test Acc: {acc:.4f} | SHAP: X={shap_mean[0]:.4f}, Y={shap_mean[1]:.4f}, A={shap_mean[2]:.4f}, B={shap_mean[3]:.4f}, EOS={shap_mean[4]:.4f}, Total={total_shap:.4f}")

    return results


# MAIN EXECUTION

print("=" * 80)
print("Training RNN Model with SHAP Analysis")
print("=" * 80)
print()

# Create dataset
full_dataset = GrammarDataset(n_samples=2000)

train_size = int(0.8 * len(full_dataset))
test_size  = len(full_dataset) - train_size

train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                          shuffle=True, collate_fn=collate)

test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                          shuffle=False, collate_fn=collate)

# Train model
model = RNNModel()
results = train_model_with_shap(model, train_loader, test_loader, full_dataset)

# Convert to DataFrame
df = pd.DataFrame(results)

# Reorder columns for better readability
df = df[['epoch', 'accuracy', 'shap_X', 'shap_Y', 'shap_A', 'shap_B', 'shap_EOS', 'shap_total']]

# Save to CSV
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"rnn_shap_results_{timestamp}.csv"
df.to_csv(csv_filename, index=False)

print()
print("=" * 80)
print(f"Training Complete!")
print("=" * 80)
print(f"Final Accuracy: {results[-1]['accuracy']:.4f}")
print(f"Final Total SHAP: {results[-1]['shap_total']:.4f}")
print(f"\nResults saved to: {csv_filename}")
print()
print("First 5 rows:")
print(df.head())
print()
print("Last 5 rows:")
print(df.tail())
print()
print("Summary Statistics:")
print(df.describe())

# Download the CSV file (for Colab)
from google.colab import files
files.download(csv_filename)
print(f"\n✓ CSV file downloaded: {csv_filename}")
# Out:
# ================================================================================
# Training RNN Model with SHAP Analysis
# ================================================================================
#
# Epoch 10/300 | Test Acc: 0.5950 | SHAP: X=0.0000, Y=0.0001, A=0.0017, B=0.0170, EOS=0.0073, Total=0.0262
# Epoch 20/300 | Test Acc: 0.5650 | SHAP: X=0.0000, Y=0.0000, A=0.0001, B=0.0048, EOS=0.0023, Total=0.0072
# Epoch 30/300 | Test Acc: 0.7125 | SHAP: X=0.0011, Y=0.0059, A=0.0087, B=0.0936, EOS=0.0212, Total=0.1305
# Epoch 40/300 | Test Acc: 0.6700 | SHAP: X=0.0003, Y=0.0027, A=0.0038, B=0.0641, EOS=0.0104, Total=0.0813
# Epoch 50/300 | Test Acc: 0.6900 | SHAP: X=0.0002, Y=0.0106, A=0.0057, B=0.0764, EOS=0.0280, Total=0.1210
# Epoch 60/300 | Test Acc: 0.9475 | SHAP: X=0.0013, Y=0.0345, A=0.0337, B=0.2406, EOS=0.0989, Total=0.4090
# Epoch 70/300 | Test Acc: 1.0000 | SHAP: X=0.0030, Y=0.1006, A=0.0841, B=0.5776, EOS=0.2525, Total=1.0178
# Epoch 80/300 | Test Acc: 1.0000 | SHAP: X=0.0028, Y=0.0975, A=0.1057, B=0.5360, EOS=0.2440, Total=0.9860
# Epoch 90/300 | Test Acc: 1.0000 | SHAP: X=0.0034, Y=0.1069, A=0.0866, B=0.4229, EOS=0.2005, Total=0.8203
# Epoch 100/300 | Test Acc: 0.5675 | SHAP: X=0.0028, Y=0.0027, A=0.0051, B=0.0282, EOS=0.0089, Total=0.0475
# Epoch 110/300 | Test Acc: 0.5550 | SHAP: X=0.0104, Y=0.0205, A=0.0129, B=0.0502, EOS=0.0367, Total=0.1306
# Epoch 120/300 | Test Acc: 0.8900 | SHAP: X=0.0305, Y=0.0581, A=0.0210, B=0.1750, EOS=0.0870, Total=0.3717
# Epoch 130/300 | Test Acc: 0.9350 | SHAP: X=0.0441, Y=0.0884, A=0.0375, B=0.3151, EOS=0.1352, Total=0.6203
# Epoch 140/300 | Test Acc: 0.9800 | SHAP: X=0.0595, Y=0.1307, A=0.0341, B=0.3041, EOS=0.1469, Total=0.6754
# Epoch 150/300 | Test Acc: 1.0000 | SHAP: X=0.0494, Y=0.1125, A=0.0417, B=0.3736, EOS=0.1677, Total=0.7449
# Epoch 160/300 | Test Acc: 1.0000 | SHAP: X=0.0875, Y=0.2157, A=0.0444, B=0.3504, EOS=0.1760, Total=0.8739
# Epoch 170/300 | Test Acc: 1.0000 | SHAP: X=0.0611, Y=0.1196, A=0.0340, B=0.3834, EOS=0.1606, Total=0.7587
# Epoch 180/300 | Test Acc: 1.0000 | SHAP: X=0.0920, Y=0.1944, A=0.0378, B=0.4162, EOS=0.1688, Total=0.9092
# Epoch 190/300 | Test Acc: 1.0000 | SHAP: X=0.0980, Y=0.1918, A=0.0400, B=0.4141, EOS=0.1782, Total=0.9221
# Epoch 200/300 | Test Acc: 1.0000 | SHAP: X=0.0752, Y=0.1538, A=0.0442, B=0.4558, EOS=0.2084, Total=0.9374
# Epoch 210/300 | Test Acc: 0.9650 | SHAP: X=0.0565, Y=0.0955, A=0.0322, B=0.1548, EOS=0.0799, Total=0.4190
# Epoch 220/300 | Test Acc: 0.9950 | SHAP: X=0.0576, Y=0.0939, A=0.0440, B=0.2417, EOS=0.1054, Total=0.5426
# Epoch 230/300 | Test Acc: 0.9900 | SHAP: X=0.0741, Y=0.1157, A=0.0438, B=0.2529, EOS=0.1181, Total=0.6047
# Epoch 240/300 | Test Acc: 0.6125 | SHAP: X=0.0922, Y=0.1925, A=0.0450, B=0.2327, EOS=0.1238, Total=0.6862
# Epoch 250/300 | Test Acc: 0.9950 | SHAP: X=0.0845, Y=0.1287, A=0.0471, B=0.2694, EOS=0.1271, Total=0.6568
# Epoch 260/300 | Test Acc: 1.0000 | SHAP: X=0.0673, Y=0.1220, A=0.0380, B=0.2449, EOS=0.1309, Total=0.6030
# Epoch 270/300 | Test Acc: 1.0000 | SHAP: X=0.0771, Y=0.1114, A=0.0446, B=0.2464, EOS=0.1326, Total=0.6122
# Epoch 280/300 | Test Acc: 0.9950 | SHAP: X=0.0786, Y=0.1516, A=0.0608, B=0.3362, EOS=0.1759, Total=0.8031
# Epoch 290/300 | Test Acc: 0.8350 | SHAP: X=0.0729, Y=0.1406, A=0.0572, B=0.3636, EOS=0.1440, Total=0.7783
# Epoch 300/300 | Test Acc: 0.9900 | SHAP: X=0.0513, Y=0.0954, A=0.0316, B=0.2736, EOS=0.1065, Total=0.5583
#
# ================================================================================
# Training Complete!
# ================================================================================
# Final Accuracy: 0.9900
# Final Total SHAP: 0.5583
#
# Results saved to: rnn_shap_results_20260225_150019.csv
#
# First 5 rows:
#    epoch  accuracy        shap_X        shap_Y        shap_A    shap_B  \
# 0      1    0.4825  3.688137e-10  4.561964e-10  7.196809e-08  0.000362
# 1      2    0.5600  2.506474e-06  2.376794e-06  4.372685e-05  0.003985
# 2      3    0.5925  3.023273e-05  1.992093e-05  3.002081e-04  0.008231
# 3      4    0.6150  1.847576e-03  2.268939e-03  9.373717e-03  0.046494
# 4      5    0.5825  5.758379e-05  1.877861e-05  6.798417e-04  0.005691
#
#    shap_EOS  shap_total
# 0  0.000259    0.000621
# 1  0.001220    0.005254
# 2  0.002858    0.011439
# 3  0.014499    0.074484
# 4  0.002842    0.009288
#
# Last 5 rows:
#      epoch  accuracy    shap_X    shap_Y    shap_A    shap_B  shap_EOS  \
# 295    296    1.0000  0.111977  0.219876  0.051949  0.338180  0.157514
# 296    297    0.9350  0.051742  0.110152  0.029068  0.242974  0.114273
# 297    298    0.9725  0.054932  0.110248  0.027968  0.235370  0.108179
# 298    299    0.9850  0.054580  0.113007  0.028701  0.250341  0.118364
# 299    300    0.9900  0.051329  0.095383  0.031615  0.273566  0.106454
#
#      shap_total
# 295    0.879497
# 296    0.548210
# 297    0.536698
# 298    0.564992
# 299    0.558348
#
# Summary Statistics:
#             epoch    accuracy        shap_X        shap_Y        shap_A  \
# count  300.000000  300.000000  3.000000e+02  3.000000e+02  3.000000e+02
# mean   150.500000    0.888717  4.153828e-02  9.245256e-02  3.631224e-02
# std     86.746758    0.168570  3.421241e-02  6.281084e-02  2.649058e-02
# min      1.000000    0.347500  3.688137e-10  4.561964e-10  7.196809e-08
# 25%     75.750000    0.806875  2.568489e-03  3.124082e-02  2.016895e-02
# 50%    150.500000    0.995000  5.227528e-02  1.026139e-01  3.672793e-02
# 75%    225.250000    1.000000  7.029615e-02  1.327920e-01  4.409493e-02
# max    300.000000    1.000000  1.308241e-01  2.553571e-01  1.356880e-01
#
#            shap_B    shap_EOS  shap_total
# count  300.000000  300.000000  300.000000
# mean     0.255321    0.117715    0.543339
# std      0.155053    0.071049    0.316738
# min      0.000362    0.000259    0.000621
# 25%      0.122816    0.061870    0.282378
# 50%      0.268337    0.131747    0.613452
# 75%      0.356780    0.161698    0.775832
# max      0.657176    0.287716    1.212630
# ✓ CSV file downloaded: rnn_shap_results_20260225_150019.csv

# %%
# Install required packages
# !pip install torch numpy shap pandas -q

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
import shap
import random
import pandas as pd
from datetime import datetime


# REPRODUCIBILITY

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# CONFIG
device = "cpu"
HIDDEN_SIZE = 60
EPOCHS = 300
BATCH_SIZE = 32
LR = 0.001
MAX_N = 8

FEATURE_NAMES = ['X', 'Y', 'A', 'B', 'EOS']
symbol_to_idx = {'X': 0, 'Y': 1, 'A': 2, 'B': 3, 'EOS': 4}

# DATA GENERATION
def generate_sequence():
    valid = np.random.rand() > 0.5
    rule = np.random.choice(['X', 'Y'])
    n = np.random.randint(1, MAX_N + 1)

    seq = [rule] + ['A'] * n

    if rule == 'X':
        seq += ['B'] * (n if valid else n + np.random.choice([-1, 1]))
    else:
        seq += ['B'] * (2*n if valid else 2*n + np.random.choice([-1, 1]))

    seq.append('EOS')
    onehot = np.eye(5)[[symbol_to_idx[s] for s in seq]]
    return onehot, float(valid)

class GrammarDataset(Dataset):
    def __init__(self, n_samples=3000):  # 3000 samples like Phi* code
        self.data = [generate_sequence() for _ in range(n_samples)]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x, y = self.data[idx]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y)

def collate(batch):
    xs, ys = zip(*batch)
    max_len = max(x.shape[0] for x in xs)
    padded = []
    for x in xs:
        pad = torch.zeros(max_len - x.shape[0], 5)
        padded.append(torch.cat([x, pad], 0))
    return torch.stack(padded), torch.tensor(ys)


# RNN MODEL

class GrammarRNN(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.rnn = nn.RNN(
            input_size=5,
            hidden_size=hidden_size,
            nonlinearity="tanh",
            batch_first=True
        )
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        _, h = self.rnn(x)
        return torch.sigmoid(self.fc(h.squeeze(0))), h  # Sigmoid in forward, matching Phi* code


# SHAP FUNCTION

def compute_shap(model, dataset):
    model.eval()

    SEQ_LEN = max(dataset.data[i][0].shape[0] for i in range(len(dataset.data)))

    def to_flat(indices):
        items = []
        for i in indices:
            x, _ = dataset.data[i]
            pad_len = SEQ_LEN - x.shape[0]
            if pad_len > 0:
                x = np.concatenate([x, np.zeros((pad_len, 5))], 0)
            items.append(x.reshape(-1))
        return torch.tensor(np.stack(items), dtype=torch.float32)

    background = to_flat(range(0, 80))
    explain    = to_flat(range(80, 120))

    class Wrapper(nn.Module):
        def __init__(self, base_model):
            super().__init__()
            self.base_model = base_model

        def forward(self, x_flat):
            x = x_flat.view(-1, SEQ_LEN, 5)
            pred, _ = self.base_model(x)  # Model returns (pred, h)
            return pred

    wrapper = Wrapper(model)
    explainer = shap.GradientExplainer(wrapper, background)

    shap_vals = explainer.shap_values(explain)
    if isinstance(shap_vals, list):
        shap_vals = shap_vals[0]

    shap_vals = np.array(shap_vals)
    shap_3d = shap_vals.reshape(shap_vals.shape[0], SEQ_LEN, 5)
    shap_mean = np.mean(np.abs(shap_3d), axis=(0,1))

    return shap_mean

# TRAIN FUNCTION

def train_model_with_shap(model, train_loader, test_loader, full_dataset):
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    criterion = nn.BCELoss()  # BCELoss like Phi* code (not BCEWithLogitsLoss)

    results = []

    for epoch in range(EPOCHS):
        # Train
        model.train()
        for x, y in train_loader:
            optimizer.zero_grad()
            pred, _ = model(x)  # Model returns (pred, h)
            loss = criterion(pred.squeeze(), y)
            loss.backward()
            optimizer.step()

        # Evaluate
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for x, y in test_loader:
                pred, _ = model(x)  # Model returns (pred, h)
                pred_binary = (pred.squeeze() > 0.5).float()
                correct += (pred_binary == y).sum().item()
                total += y.size(0)

        acc = correct / total

        # Compute SHAP
        print(f"Epoch {epoch+1}/{EPOCHS} | Computing SHAP...", end='\r')
        shap_mean = compute_shap(model, full_dataset)

        # Calculate total SHAP (sum of all features)
        total_shap = float(np.sum(shap_mean))

        # Store results
        epoch_result = {
            'epoch': epoch + 1,
            'accuracy': acc,
            'shap_X': float(shap_mean[0]),
            'shap_Y': float(shap_mean[1]),
            'shap_A': float(shap_mean[2]),
            'shap_B': float(shap_mean[3]),
            'shap_EOS': float(shap_mean[4]),
            'shap_total': total_shap
        }
        results.append(epoch_result)

        if (epoch+1) % 10 == 0:
            print(f"Epoch {epoch+1}/{EPOCHS} | Test Acc: {acc:.4f} | SHAP: X={shap_mean[0]:.4f}, Y={shap_mean[1]:.4f}, A={shap_mean[2]:.4f}, B={shap_mean[3]:.4f}, EOS={shap_mean[4]:.4f}, Total={total_shap:.4f}")

    return results

# MAIN EXECUTION

print("=" * 80)
print("Training RNN Model with SHAP Analysis")
print("Model architecture matches Phi* calculation code")
print("=" * 80)
print()

# Create dataset (3000 samples like Phi* code)
full_dataset = GrammarDataset(n_samples=3000)

train_size = int(0.8 * len(full_dataset))
test_size  = len(full_dataset) - train_size

train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                          shuffle=True, collate_fn=collate)

test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                          shuffle=False, collate_fn=collate)

# Train model
model = GrammarRNN(HIDDEN_SIZE).to(device)
results = train_model_with_shap(model, train_loader, test_loader, full_dataset)

# Convert to DataFrame
df = pd.DataFrame(results)

# Reorder columns for better readability
df = df[['epoch', 'accuracy', 'shap_X', 'shap_Y', 'shap_A', 'shap_B', 'shap_EOS', 'shap_total']]

# Save to CSV
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"rnn_shap_results_{timestamp}.csv"
df.to_csv(csv_filename, index=False)

print()
print("=" * 80)
print(f"Training Complete!")
print("=" * 80)
print(f"Final Accuracy: {results[-1]['accuracy']:.4f}")
print(f"Final Total SHAP: {results[-1]['shap_total']:.4f}")
print(f"\nResults saved to: {csv_filename}")
print()
print("First 5 rows:")
print(df.head())
print()
print("Last 5 rows:")
print(df.tail())
print()
print("Summary Statistics:")
print(df.describe())

# Download the CSV file (for Colab)
from google.colab import files
files.download(csv_filename)
print(f"\n✓ CSV file downloaded: {csv_filename}")
# Out:
# ================================================================================
# Training RNN Model with SHAP Analysis
# Model architecture matches Phi* calculation code
# ================================================================================
#
# Epoch 10/300 | Test Acc: 0.5600 | SHAP: X=0.0000, Y=0.0000, A=0.0000, B=0.0016, EOS=0.0007, Total=0.0024
# Epoch 20/300 | Test Acc: 0.6517 | SHAP: X=0.0002, Y=0.0008, A=0.0021, B=0.0151, EOS=0.0047, Total=0.0229
# Epoch 30/300 | Test Acc: 0.6667 | SHAP: X=0.0007, Y=0.0031, A=0.0015, B=0.0148, EOS=0.0065, Total=0.0266
# Epoch 40/300 | Test Acc: 0.6850 | SHAP: X=0.0006, Y=0.0018, A=0.0009, B=0.0104, EOS=0.0037, Total=0.0175
# Epoch 50/300 | Test Acc: 0.6850 | SHAP: X=0.0009, Y=0.0032, A=0.0014, B=0.0132, EOS=0.0054, Total=0.0242
# Epoch 60/300 | Test Acc: 0.9050 | SHAP: X=0.0022, Y=0.0111, A=0.0038, B=0.0352, EOS=0.0182, Total=0.0704
# Epoch 70/300 | Test Acc: 1.0000 | SHAP: X=0.0017, Y=0.0161, A=0.0090, B=0.0511, EOS=0.0207, Total=0.0986
# Epoch 80/300 | Test Acc: 1.0000 | SHAP: X=0.0016, Y=0.0086, A=0.0040, B=0.0283, EOS=0.0179, Total=0.0604
# Epoch 90/300 | Test Acc: 1.0000 | SHAP: X=0.0014, Y=0.0079, A=0.0056, B=0.0451, EOS=0.0174, Total=0.0776
# Epoch 100/300 | Test Acc: 1.0000 | SHAP: X=0.0015, Y=0.0076, A=0.0056, B=0.0405, EOS=0.0133, Total=0.0686
# Epoch 110/300 | Test Acc: 0.8317 | SHAP: X=0.0009, Y=0.0053, A=0.0034, B=0.0335, EOS=0.0200, Total=0.0630
# Epoch 120/300 | Test Acc: 1.0000 | SHAP: X=0.0014, Y=0.0104, A=0.0050, B=0.0347, EOS=0.0183, Total=0.0697
# Epoch 130/300 | Test Acc: 1.0000 | SHAP: X=0.0009, Y=0.0064, A=0.0058, B=0.0380, EOS=0.0219, Total=0.0731
# Epoch 140/300 | Test Acc: 1.0000 | SHAP: X=0.0011, Y=0.0084, A=0.0082, B=0.0426, EOS=0.0201, Total=0.0803
# Epoch 150/300 | Test Acc: 0.9833 | SHAP: X=0.0012, Y=0.0059, A=0.0033, B=0.0241, EOS=0.0186, Total=0.0530
# Epoch 160/300 | Test Acc: 1.0000 | SHAP: X=0.0014, Y=0.0083, A=0.0053, B=0.0278, EOS=0.0208, Total=0.0636
# Epoch 170/300 | Test Acc: 1.0000 | SHAP: X=0.0020, Y=0.0087, A=0.0047, B=0.0296, EOS=0.0210, Total=0.0659
# Epoch 180/300 | Test Acc: 1.0000 | SHAP: X=0.0011, Y=0.0053, A=0.0039, B=0.0289, EOS=0.0193, Total=0.0586
# Epoch 190/300 | Test Acc: 1.0000 | SHAP: X=0.0012, Y=0.0059, A=0.0033, B=0.0223, EOS=0.0161, Total=0.0488
# Epoch 200/300 | Test Acc: 1.0000 | SHAP: X=0.0011, Y=0.0053, A=0.0046, B=0.0297, EOS=0.0179, Total=0.0586
# Epoch 210/300 | Test Acc: 0.5450 | SHAP: X=0.0000, Y=0.0000, A=0.0001, B=0.0016, EOS=0.0021, Total=0.0037
# Epoch 220/300 | Test Acc: 0.6917 | SHAP: X=0.0003, Y=0.0010, A=0.0009, B=0.0131, EOS=0.0089, Total=0.0243
# Epoch 230/300 | Test Acc: 1.0000 | SHAP: X=0.0021, Y=0.0051, A=0.0033, B=0.0193, EOS=0.0166, Total=0.0464
# Epoch 240/300 | Test Acc: 1.0000 | SHAP: X=0.0010, Y=0.0039, A=0.0043, B=0.0150, EOS=0.0174, Total=0.0416
# Epoch 250/300 | Test Acc: 0.9800 | SHAP: X=0.0009, Y=0.0039, A=0.0036, B=0.0221, EOS=0.0222, Total=0.0528
# Epoch 260/300 | Test Acc: 1.0000 | SHAP: X=0.0017, Y=0.0050, A=0.0029, B=0.0253, EOS=0.0121, Total=0.0469
# Epoch 270/300 | Test Acc: 0.9750 | SHAP: X=0.0366, Y=0.0993, A=0.0093, B=0.0257, EOS=0.0288, Total=0.1996
# Epoch 280/300 | Test Acc: 1.0000 | SHAP: X=0.0510, Y=0.1443, A=0.0082, B=0.0358, EOS=0.0179, Total=0.2572
# Epoch 290/300 | Test Acc: 1.0000 | SHAP: X=0.0603, Y=0.1656, A=0.0088, B=0.0338, EOS=0.0196, Total=0.2880
# Epoch 300/300 | Test Acc: 1.0000 | SHAP: X=0.0243, Y=0.0644, A=0.0048, B=0.0246, EOS=0.0173, Total=0.1353
#
# ================================================================================
# Training Complete!
# ================================================================================
# Final Accuracy: 1.0000
# Final Total SHAP: 0.1353
#
# Results saved to: rnn_shap_results_20260226_090413.csv
#
# First 5 rows:
#    epoch  accuracy        shap_X        shap_Y    shap_A    shap_B  shap_EOS  \
# 0      1  0.508333  1.747758e-08  1.980740e-08  0.000001  0.000340  0.000155
# 1      2  0.468333  1.640778e-06  7.885366e-07  0.000025  0.000416  0.000248
# 2      3  0.476667  3.178332e-07  1.781314e-07  0.000006  0.000229  0.000197
# 3      4  0.488333  1.583136e-06  6.452437e-08  0.000040  0.000444  0.000254
# 4      5  0.508333  3.350543e-07  1.452888e-07  0.000005  0.000411  0.000281
#
#    shap_total
# 0    0.000496
# 1    0.000691
# 2    0.000433
# 3    0.000739
# 4    0.000698
#
# Last 5 rows:
#      epoch  accuracy    shap_X    shap_Y    shap_A    shap_B  shap_EOS  \
# 295    296  1.000000  0.026866  0.073234  0.005597  0.027862  0.016401
# 296    297  1.000000  0.014948  0.039960  0.003766  0.026933  0.018744
# 297    298  0.885000  0.026385  0.070151  0.007957  0.038827  0.023245
# 298    299  0.993333  0.020776  0.053856  0.005330  0.031426  0.023316
# 299    300  1.000000  0.024274  0.064351  0.004789  0.024568  0.017333
#
#      shap_total
# 295    0.149960
# 296    0.104352
# 297    0.166565
# 298    0.134704
# 299    0.135315
#
# Summary Statistics:
#             epoch    accuracy        shap_X        shap_Y      shap_A  \
# count  300.000000  300.000000  3.000000e+02  3.000000e+02  300.000000
# mean   150.500000    0.882844  3.509419e-03  1.202520e-02    0.003734
# std     86.746758    0.176346  8.155318e-03  2.184856e-02    0.002230
# min      1.000000    0.468333  1.747758e-08  1.980740e-08    0.000001
# 25%     75.750000    0.691667  6.782060e-04  2.822529e-03    0.001646
# 50%    150.500000    1.000000  1.109171e-03  6.396068e-03    0.004141
# 75%    225.250000    1.000000  1.772018e-03  9.522680e-03    0.005271
# max    300.000000    1.000000  6.030032e-02  1.655971e-01    0.009259
#
#            shap_B    shap_EOS  shap_total
# count  300.000000  300.000000  300.000000
# mean     0.025144    0.014084    0.058497
# std      0.013133    0.006969    0.041122
# min      0.000229    0.000155    0.000433
# 25%      0.015238    0.008490    0.029737
# 50%      0.026975    0.016482    0.061241
# 75%      0.034417    0.019045    0.071826
# max      0.054734    0.028788    0.288025
# ✓ CSV file downloaded: rnn_shap_results_20260226_090413.csv

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV files
phi_df = pd.read_csv('/content/rnn_training_summary.csv')  # Columns: 'epoch', 'phi'
shap_df = pd.read_csv('/content/rnn_shap_results_20260226_090413.csv')  # Columns: 'epoch', 'shap_total'

# Add epoch if missing
if 'epoch' not in phi_df.columns:
    phi_df['epoch'] = range(1, len(phi_df) + 1)
if 'epoch' not in shap_df.columns:
    shap_df['epoch'] = range(1, len(shap_df) + 1)

# Merge on epoch
merged_df = pd.merge(phi_df, shap_df, on='epoch')

# Compute correlations
pearson_corr, pearson_p = pearsonr(merged_df['phi'], merged_df['shap_total'])
spearman_corr, spearman_p = spearmanr(merged_df['phi'], merged_df['shap_total'])

print(f"Pearson correlation: {pearson_corr:.4f}, p-value: {pearson_p:.4e}")
print(f"Spearman correlation: {spearman_corr:.4f}, p-value: {spearman_p:.4e}")

# Plot
plt.figure(figsize=(8,6))
sns.regplot(x='phi', y='shap_total', data=merged_df, ci=None,
            scatter_kws={'s':50, 'alpha':0.6}, line_kws={'color':'red'})
plt.title('Correlation between Φ* and SHAP values', fontsize=14)
plt.xlabel('Φ* (phi)', fontsize=12)
plt.ylabel('SHAP Total', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

# Annotate correlation coefficients
plt.text(0.05, 0.95, f"Pearson r = {pearson_corr:.4f}\nSpearman ρ = {spearman_corr:.4f}",
         transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top',
         bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray'))

plt.tight_layout()
plt.show()
# Out:
# Pearson correlation: -0.2714, p-value: 1.8304e-06
# Spearman correlation: -0.1607, p-value: 5.2650e-03
